# %% [markdown]
# <a href="https://colab.research.google.com/github/syafri06/syafri06.github.io/blob/main/ASSIGNMENT_Lesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ASSIGNMENT 3**
#
# Mengimport Library yang diperlukan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# **1) a) Meload dataset dari google drive menggunakan Library Pandas**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trends_df = pd.read_csv("/content/drive/MyDrive/Dataset/Shopping Trend/shopping_trends.csv",delimiter=",")
trends_df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
behavior_df = pd.read_csv("/content/drive/MyDrive/Dataset/Shopping Trend/shopping_behavior_updated.csv",delimiter=",")
behavior_df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
trends_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
behavior_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# **b. Menghitung ukuran statistik dengan Library Numpy pada dataset**

# %%
np.mean(trends_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Customer ID              1950.500000
# Age                        44.068462
# Purchase Amount (USD)      59.764359
# Review Rating               3.749949
# Previous Purchases         25.351538
# dtype: float64

# %%
np.min(trends_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# Customer ID                              1
# Age                                     18
# Gender                              Female
# Item Purchased                    Backpack
# Category                       Accessories
# Purchase Amount (USD)                   20
# Location                           Alabama
# Size                                     L
# Color                                Beige
# Season                                Fall
# Review Rating                          2.5
# Subscription Status                     No
# Payment Method               Bank Transfer
# Shipping Type               2-Day Shipping
# Discount Applied                        No
# ...

# %%
np.max(trends_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# Customer ID                         3900
# Age                                   70
# Gender                              Male
# Item Purchased                   T-shirt
# Category                       Outerwear
# Purchase Amount (USD)                100
# Location                         Wyoming
# Size                                  XL
# Color                             Yellow
# Season                            Winter
# Review Rating                        5.0
# Subscription Status                  Yes
# Payment Method                     Venmo
# Shipping Type               Store Pickup
# Discount Applied                     Yes
# ...

# %%
np.std(trends_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3571: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Customer ID              1125.832988
# Age                        15.205639
# Purchase Amount (USD)      23.682355
# Review Rating               0.716131
# Previous Purchases         14.445273
# dtype: float64

# %%
np.var(trends_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3713: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Customer ID              1.267500e+06
# Age                      2.312115e+02
# Purchase Amount (USD)    5.608540e+02
# Review Rating            5.128436e-01
# Previous Purchases       2.086659e+02
# dtype: float64

# %% [markdown]
# **c. melakukan penggabungan dan pengelompokkan data**

# %%
merge = trends_df.merge(behavior_df, how = 'right')
merge.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
trends_df.groupby(by=["Gender", "Category"]).agg({
    "Age": "mean",
    "Purchase Amount (USD)": "sum",
    "Review Rating" : "mean"
})
# Out:
#                           Age  Purchase Amount (USD)  Review Rating
# Gender Category
# Female Accessories  44.283163                  23819       3.755612
#        Clothing     43.620504                  33636       3.704496
#        Footwear     44.482412                  11835       3.822111
#        Outerwear    44.128713                   5901       3.730693
# Male   Accessories  44.196934                  50381       3.774646
#        Clothing     43.859441                  70628       3.731922
#        Footwear     44.422500                  24258       3.775000
#        Outerwear    44.394619                  12623       3.754260

# %% [markdown]
# **d. Menambahkan baris dan kolom baru dengan loc dan iloc**

# %%
trends_df.loc[3899]
# Out:
# Customer ID                          3900
# Age                                    52
# Gender                             Female
# Item Purchased                    Handbag
# Category                      Accessories
# Purchase Amount (USD)                  81
# Location                       California
# Size                                    M
# Color                               Beige
# Season                             Spring
# Review Rating                         3.1
# Subscription Status                    No
# Payment Method              Bank Transfer
# Shipping Type                Store Pickup
# Discount Applied                       No
# Promo Code Used                        No
# Previous Purchases                     33
# Preferred Payment Method            Venmo
# Frequency of Purchases          Quarterly
# Name: 3899, dtype: object

# %%
trends_df.loc[3900] = ['3900','32','Male','Blouse','Clothing','50','California','L','Beige','Winter','3.1','No','Bank Transfer','Store Pickup','No','No','33','Venmo','Quartely']

# %%
trends_df.loc[3900]
# Out:
# Customer ID                          3900
# Age                                    32
# Gender                               Male
# Item Purchased                     Blouse
# Category                         Clothing
# Purchase Amount (USD)                  50
# Location                       California
# Size                                    L
# Color                               Beige
# Season                             Winter
# Review Rating                         3.1
# Subscription Status                    No
# Payment Method              Bank Transfer
# Shipping Type                Store Pickup
# Discount Applied                       No
# Promo Code Used                        No
# Previous Purchases                     33
# Preferred Payment Method            Venmo
# Frequency of Purchases           Quartely
# Name: 3900, dtype: object

# %%
trends_df.iloc[0]
# Out:
# Customer ID                           1
# Age                                  55
# Gender                             Male
# Item Purchased                   Blouse
# Category                       Clothing
# Purchase Amount (USD)                53
# Location                       Kentucky
# Size                                  L
# Color                              Gray
# Season                           Winter
# Review Rating                       3.1
# Subscription Status                 Yes
# Payment Method              Credit Card
# Shipping Type                   Express
# Discount Applied                    Yes
# Promo Code Used                     Yes
# Previous Purchases                   14
# Preferred Payment Method          Venmo
# Frequency of Purchases      Fortnightly
# Name: 0, dtype: object

# %%
trends_df.iloc[0,1]
# Out:
# 55

# %%
trends_df.iloc[0, 1] = 45
trends_df.head()
# Out:
#   Customer ID Age Gender Item Purchased  Category Purchase Amount (USD)  \
# 0           1  45   Male         Blouse  Clothing                    53
# 1           2  19   Male        Sweater  Clothing                    64
# 2           3  50   Male          Jeans  Clothing                    73
# 3           4  21   Male        Sandals  Footwear                    90
# 4           5  45   Male         Blouse  Clothing                    49
#
#         Location Size      Color  Season Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter           3.1                 Yes
# 1          Maine    L     Maroon  Winter           3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring           3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring           3.5                 Yes
# 4         Oregon    M  Turquoise  Spring           2.7                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# ...

# %% [markdown]
# **e. Menerapkan ekspresi lambda**

# %%
trends_df[['Review Rating']].apply(lambda x : x*10)
# Out:
#                        Review Rating
# 0                               31.0
# 1                               31.0
# 2                               31.0
# 3                               35.0
# 4                               27.0
# ...                              ...
# 3896                            45.0
# 3897                            29.0
# 3898                            38.0
# 3899                            31.0
# 3900  3.13.13.13.13.13.13.13.13.13.1
#
# [3901 rows x 1 columns]
